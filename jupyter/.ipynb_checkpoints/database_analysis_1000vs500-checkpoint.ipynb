# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import cv2
import pickle
import collections
import seaborn as sns
import glob
from matplotlib.pyplot import *
from utility import *
from pathos.multiprocessing import ProcessingPool, ThreadingPool
from os.path import basename, splitext

# %%
def heatmap(data, row_labels, col_labels, ax=None,
            cbar_kw={}, plot_title="", cbarlabel="", color_bar=True, **kwargs):
    """
    Create a heatmap from a numpy array and two lists of labels.

    Parameters
    ----------
    data
        A 2D numpy array of shape (N, M).
    row_labels
        A list or array of length N with the labels for the rows.
    col_labels
        A list or array of length M with the labels for the columns.
    ax
        A `matplotlib.axes.Axes` instance to which the heatmap is plotted.  If
        not provided, use current axes or create a new one.  Optional.
    cbar_kw
        A dictionary with arguments to `matplotlib.Figure.colorbar`.  Optional.
    cbarlabel
        The label for the colorbar.  Optional.
    **kwargs
        All other arguments are forwarded to `imshow`.
    """

    if not ax:
        ax = gca()

    # Plot the heatmap
    im = ax.imshow(data, **kwargs)

    # Create colorbar
    cbar = None
    if color_bar:
        cbar = ax.figure.colorbar(im, ax=ax, **cbar_kw)
        cbar.ax.set_ylabel(cbarlabel, rotation=-90, va="bottom")

    # We want to show all ticks...
    ax.set_xticks(np.arange(data.shape[1]))
    ax.set_yticks(np.arange(data.shape[0]))
    # ... and label them with the respective list entries.
    ax.set_xticklabels(col_labels)
    ax.set_yticklabels(row_labels)

    # Let the horizontal axes labeling appear on top.
    ax.tick_params(top=True, bottom=False,
                   labeltop=True, labelbottom=False)

    # Rotate the tick labels and set their alignment.
    setp(ax.get_xticklabels(), rotation=-30, ha="right",
             rotation_mode="anchor")

    # Turn spines off and create white grid.
    for edge, spine in ax.spines.items():
        spine.set_visible(False)

    ax.set_xticks(np.arange(data.shape[1]+1)-.5, minor=True)
    ax.set_yticks(np.arange(data.shape[0]+1)-.5, minor=True)
    ax.grid(which="minor", color="w", linestyle='-', linewidth=3)
    ax.tick_params(which="minor", bottom=False, left=False)
    ax.set_title(plot_title)

    return im, cbar


def annotate_heatmap(im, data=None, valfmt="{x:.2f}",
                     textcolors=["black", "white"],
                     threshold=None, **textkw):
    """
    A function to annotate a heatmap.

    Parameters
    ----------
    im
        The AxesImage to be labeled.
    data
        Data used to annotate.  If None, the image's data is used.  Optional.
    valfmt
        The format of the annotations inside the heatmap.  This should either
        use the string format method, e.g. "$ {x:.2f}", or be a
        `matplotlib.ticker.Formatter`.  Optional.
    textcolors
        A list or array of two color specifications.  The first is used for
        values below a threshold, the second for those above.  Optional.
    threshold
        Value in data units according to which the colors from textcolors are
        applied.  If None (the default) uses the middle of the colormap as
        separation.  Optional.
    **kwargs
        All other arguments are forwarded to each call to `text` used to create
        the text labels.
    """

    if not isinstance(data, (list, np.ndarray)):
        data = im.get_array()

    # Normalize the threshold to the images color range.
    if threshold is not None:
        threshold = im.norm(threshold)
    else:
        threshold = im.norm(data.max())/2.

    # Set default alignment to center, but allow it to be
    # overwritten by textkw.
    kw = dict(horizontalalignment="center",
              verticalalignment="center")
    kw.update(textkw)

    # Get the formatter in case a string is supplied
    if isinstance(valfmt, str):
        valfmt = matplotlib.ticker.StrMethodFormatter(valfmt)

    # Loop over the data and create a `Text` for each "pixel".
    # Change the text's color depending on the data.
    texts = []
    for i in range(data.shape[0]):
        for j in range(data.shape[1]):
            kw.update(color=textcolors[int(im.norm(data[i, j]) > threshold)])
            text = im.axes.text(j, i, valfmt(data[i, j], None), **kw)
            texts.append(text)

    return texts

# %%
def separate_outliers(x, t=1.5):
    q1 = np.percentile(x, 25)
    q3 = np.percentile(x, 75)
    m = np.median(x)
    iqr = q3-q1
    outliers = (x < q1-t*iqr) | (x>q3+t*iqr)
    return x[~outliers], x[outliers]

# %%
def get_global_stats(df):
    #average neighborhood size
    x, xp = separate_outliers(df.end-df.beg)
    x, xp = separate_outliers(x)
    boxplot(x)
def q1(x):
    return np.percentile(x, 25)
def q3(x):
    return np.percentile(x, 75)
def p95(x):
    return np.percentile(x, 95)
def p5(x):
    return np.percentile(x, 5)

# %%
def p(n):
    def pp(x):
        return np.percentile(x, n)
    return pp

# %%
def get_all_circles(rotated):
    allCircles = []
    for i, profile in enumerate(rotated):
        _kernel_size = int(np.percentile(get_cut_points(profile, profile.mean()), 25))
        #print("kernel size param %r"%_kernel_size)
        x, y, der1, der2, local_minima_2d, circles = extract_circles(np.arange(len(profile)), 
                                                             profile,
                                                             kernel_size_param=_kernel_size,
                                                             same_scale=True, verbose=False)       
        if i%300==0:
            draw_circles(x, y, circles)
            show()
        allCircles.append(circles)
    return allCircles

# %%
columns = ['profile'] + list(Circle._fields)
functions = set()
circle_functions = set()
def feature(fun):
    functions.add(fun.__name__)
    return fun

def circle_feature(fun):
    circle_functions.add(fun.__name__)
    return fun

def log(s):
    print("[*] %s"%s)
    
def p(n):
    def pp(x):
        return np.percentile(x, n)
    return pp

profile, beg, end, index, h, cx, cy, r =  'profile beg end index h cx cy r'.split()
#stats = df[[profile, r]].groupby(profile).aggregate(['mean', 'median', 'std', p(5)])
#smalles_5percent = df.apply(lambda x: x.r < stats.r.pp.loc[x.profile], axis=1)

class Features:
    circle_statistics = None
    statistics = None
    circles = None
    exceptions = []
    def __init__(self, x):
        log('Starting...')
        self.x = np.ma.array(x, mask=x<x.mean(axis=1, keepdims=True)-3*x.std(axis=1, keepdims=True))
        self.kernel_sizes = [int(np.percentile(get_cut_points(profile, profile.mean()), 25)) for profile in self.x]
        log('Kernel sizes extracted')
        self.local_minima = [get_local_minima_2d(profile, kernel_size, mn=-1) for profile, kernel_size in zip(self.x, self.kernel_sizes)]
        log('Local minima extracted')
        self.local_maxima = [get_local_minima_2d(-profile, kernel_size) for profile, kernel_size in zip(self.x, self.kernel_sizes)]
        log('Local maxima extracted')
 
    @feature
    def ra(self):
        return np.mean(np.abs(self.x-np.mean(self.x, axis=1, keepdims=True)), axis=1)

    @feature
    def rq(self):
        return np.sqrt(np.mean((self.x-np.mean(self.x, axis=1, keepdims=True))**2, axis=1))


    @feature
    def rv(self):
        return np.max(self.x-np.mean(self.x, axis=1, keepdims=True), axis=1)

    @feature
    def rz(self):
        return -np.min(self.x - np.mean(self.x, axis=1, keepdims=True), axis=1)

    @feature
    def r10_iso(self):
        return np.array([np.mean(np.sort(self.x[n][self.local_maxima[n]])[:10] ) for n in range(len(self.x))]) - \
            np.array([np.mean(np.sort(self.x[n][self.local_minima[n]])[-10:]) for n in range(len(self.x))])
    
    def get_all_circles(self):
        allCircles = []
        for i, profile in enumerate(self.x):
            try:
                x, y, der1, der2, local_minima_2d, circles = extract_circles(np.arange(len(profile)), 
                                                                     profile,
                                                                     kernel_size_param=self.kernel_sizes[i],
                                                                     same_scale=True, verbose=False)       
                if i%500==0:
                    log("Finished extracting circles from profile %5d/%5d"%(i, len(self.x)))
                allCircles.append(circles)
            except Exception as e:
                self.exceptions.append(["Exception occurred for profile %d"])
        self.circles = pd.DataFrame(((i, *circle) for i, circles in enumerate(allCircles) for circle in circles), columns=columns)   
        return self
    
    @circle_feature
    def rho(self):
        if self.circles is None:
            self.get_all_circles()
        return self.circles[['profile', 'r']].groupby('profile').aggregate('mean')
    
    @circle_feature
    def rho95(self):
        if self.circles is None:
            self.get_all_circles()       
        mardas = self.circles[['profile', 'r']].groupby('profile').aggregate(p(5))
        return self.circles[self.circles.apply(lambda x: x.r < mardas.r.loc[x.profile], axis=1)][['profile', 'r']].groupby('profile').aggregate('mean')
       
    def run_all_tests(self):
        log('Starting to run all tests.')
        self.run_all_rhos()
        return self.run_all_non_rhos()
    
    def run_all_non_rhos(self):
        log('Starting to get global properties')
        if self.statistics is None:
            self.statistics = pd.DataFrame({name: getattr(self, name)() for name in functions})
        return self
    
    def run_all_rhos(self):
        log('Starting to get global properties')
        if self.circle_statistics is None:
            circle_statistics = {name: getattr(self, name)() for name in circle_functions}
        self.circle_statistics = pd.concat((x for x in circle_statistics.values()), axis=1)
        self.circle_statistics.columns = circle_statistics.keys()
    #self.circle_statistics = {name: getattr(self, name)() for name in circle_functions}
        return self
        

#GlobalFeatures = collections.namedtuple('GlobalFeatures', functions)

# %%
functions
# Out:
# {'r10_iso', 'ra', 'rq', 'rv', 'rz'}

# %%
def random_sub_image(img, ratio=.5):
    w, h = img.shape
    ww, hh = int(ratio*w), int(ratio*h)
    x, y = np.random.randint(max(1,w-ww)), np.random.randint(max(1,h-hh))
    return img[x:x+ww, y:y+hh]

def random_sub_length_image(img, ratio=.5):
    w, h = img.shape
    ww, hh = int(w), int(ratio*h)
    x, y = 0, np.random.randint(max(1,h-hh))
    #print(x, y)
    return img[:, y:y+hh]

def random_sub_width_image(img, ratio=.5):
    w, h = img.shape
    ww, hh = int(w*h), int(ratio)
    x, y = np.random.randint(max(1,w-ww)), 0
    return img[x:x+ww, :]

# %%
images_mapper = {
          'Normal': lambda x:x, 
          'Smoothed': lambda x: cv2.pyrUp(cv2.pyrDown((x))),
#          '50% area rotate': lambda x: align_image(random_sub_image(x)),
#          '50% area tilt': lambda x: adjust_tilt(random_sub_image(x)),
#          '25% area': lambda x: random_sub_image(x, .05),
#          '50% length': lambda x: random_sub_length_image(x),
#          '50% length rotate': lambda x: align_image(random_sub_length_image(x)),
#          '50% length tilt': lambda x: adjust_tilt(random_sub_length_image(x)),
#          '50% width': lambda x: random_sub_width_image(x),
#          '50% width tilt': lambda x: adjust_tilt(random_sub_width_image(x)),
#          'Rotated': lambda x: align_image(x),
#          'Tilted': lambda x: adjust_tilt(x),
#          'Tilted & Rotated': lambda x: adjust_tilt(align_image(x))
                }

# %%
file_names = glob.glob('dataset/1000x/*_2.np')
file_names
#with ThreadingPool(2) as t:
#    stats_list = t.map(get_all_stats, file_names)
#stats_list = get_all_stats(file_names[0])
# Out:
# ['dataset/1000x/A500_2.np', 'dataset/1000x/A1000_2.np']

# %%
def foo(args):
    (k, f), x = args
    return (k, f(x))
def get_all_stats(file_name):
    with open(file_name, 'rb') as f:
        img = pickle.load(f)
    images = dict(foo(x) for x in zip(images_mapper.items(), [img]*len(images_mapper)))
    with ProcessingPool() as pool:
        images_features = pool.map(Features, images.values())
    with ProcessingPool() as pool:
        images_features = pool.map(lambda x: x.run_all_tests(), images_features)
    return images_features
#with ThreadingPool(4) as t:
#    result = t.map(get_all_stats, file_names)

# %%
#stats = {name: feature[0].statistics for name, feature in zip(file_names, result)}
stats = {f_name:{k:feature.statistics for k, feature in zip(images_mapper, features)} for f_name, features in zip(file_names, result)}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0f03eefd1728> in <module>
#       1 #stats = {name: feature[0].statistics for name, feature in zip(file_names, result)}
# ----> 2 stats = {f_name:{k:feature.statistics for k, feature in zip(images_mapper, features)} for f_name, features in zip(file_names, result)}
#
# NameError: name 'result' is not defined

# %%
#circle_stats = {name: mardas(feature[0]) for name, feature in zip(file_names, result)}
#circle_stats = {name: feature[0].circle_statistics for name, feature in zip(file_names, result)}
circle_stats = {f_name:{k:feature.circle_statistics for k, feature in zip(images_mapper, features)} for f_name, features in zip(file_names, result)}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-9ded50874dfd> in <module>
#       1 #circle_stats = {name: mardas(feature[0]) for name, feature in zip(file_names, result)}
#       2 #circle_stats = {name: feature[0].circle_statistics for name, feature in zip(file_names, result)}
# ----> 3 circle_stats = {f_name:{k:feature.circle_statistics for k, feature in zip(images_mapper, features)} for f_name, features in zip(file_names, result)}
#
# NameError: name 'result' is not defined

# %%
with open('dataset/1000x/comparison_local_stats.pkl', 'rb') as f:
    circle_stats = pickle.load(f)
with open('dataset/1000x/comparison_global_stats.pkl', 'rb') as f:
    stats = pickle.load(f)

# %%
name_dict = {'ra':"$R_a$", 'rq':"$R_q$", 'rv':"$R_v$", 'rz':"$R_z$", 'r10_iso':"$R_{10(ISO)}$"}
names = images_mapper.keys() - set('50% area rotate; 50% area tilt; 50% length tilt; 50% width tilt; 50% length rotate; 50% length tilt'.split('; '))
statistics = ['mean', 'std']
data = pd.DataFrame(
    [(file_name, name_dict[column], name, statistic, stat[name][column].describe()[statistic])
     for file_name, stat in stats.items()
     for i,name in enumerate(names) 
     for column in stat[name].columns
     for statistic in statistics],
    columns=["File Name", 'Measure', 'Variation', 'Statistics', 'Statistic Value($\mu m$)'])

# %%
data['File Name'] = data['File Name'].apply(lambda x: x.split('/')[-1].split('_')[0][1:]+'x')
data = pd.concat([v2.assign(**{"File Name": k, "Variation": k2}) for k, v in stats.items() for k2, v2 in v.items() ])

# %%
from scipy.stats import ttest_ind

# %%
cols = "ra 	rz 	rq 	rv 	r10_iso".split()
for col in cols:
    res = ttest_ind(
        data[col][(data["Variation"]=="Normal") & data["File Name"].str.contains("A500")], 
        data[col][(data["Variation"]=="Normal") & data["File Name"].str.contains("A1000")], equal_var=False, nan_policy="omit")
    print(col, res.pvalue)
# Out:
# ra 1.7659500267072937e-12
# rz 4.490124108155195e-08
# rq 2.1851416245735453e-06
# rv 0.7958427536501924
# r10_iso 2.2123266955531236e-121

# %%
data2 = data.set_index(["File Name", "Variation"]).stack().reset_index()\
    .rename(columns={"level_2": "Measure", 0: "Statistic Value($\mu m$)"})
data2["Resolution"] = data2["File Name"].map(lambda x: x.split("/")[-1][1:].split("_")[0]+"x")
data2
# Out:
#                       File Name Variation  Measure  Statistic Value($\mu m$)  \
# 0      dataset/1000x/A1000_2.np    Normal       ra                 12.319227
# 1      dataset/1000x/A1000_2.np    Normal       rz                 28.424331
# 2      dataset/1000x/A1000_2.np    Normal       rq                 14.939845
# 3      dataset/1000x/A1000_2.np    Normal       rv                 46.622550
# 4      dataset/1000x/A1000_2.np    Normal  r10_iso                 52.688185
# 5      dataset/1000x/A1000_2.np    Normal       ra                 12.252274
# 6      dataset/1000x/A1000_2.np    Normal       rz                 27.979056
# 7      dataset/1000x/A1000_2.np    Normal       rq                 14.816711
# 8      dataset/1000x/A1000_2.np    Normal       rv                 45.489293
# 9      dataset/1000x/A1000_2.np    Normal  r10_iso                 50.436546
# 10     dataset/1000x/A1000_2.np    Normal       ra                 12.181250
# 11     dataset/1000x/A1000_2.np    Normal       rz                 27.508076
# 12     dataset/1000x/A1000_2.np    Normal       rq                 14.691865
# 13     dataset/1000x/A1000_2.np    Normal       rv                 44.265761
# 14     dataset/1000x/A1000_2.np    Normal  r10_iso                 50.141762
# 15     dataset/1000x/A1000_2.np    Normal       ra                 12.105322
# 16     dataset/1000x/A1000_2.np    Normal       rz                 27.010274
# 17     dataset/1000x/A1000_2.np    Normal       rq                 14.562313
# 18     dataset/1000x/A1000_2.np    Normal       rv                 43.004305
# 19     dataset/1000x/A1000_2.np    Normal  r10_iso                 49.757928
# 20     dataset/1000x/A1000_2.np    Normal       ra                 12.028654
# 21     dataset/1000x/A1000_2.np    Normal       rz                 26.483810
# 22     dataset/1000x/A1000_2.np    Normal       rq                 14.432508
# 23     dataset/1000x/A1000_2.np    Normal       rv                 41.819984
# 24     dataset/1000x/A1000_2.np    Normal  r10_iso                 49.638780
# 25     dataset/1000x/A1000_2.np    Normal       ra                 11.945812
# 26     dataset/1000x/A1000_2.np    Normal       rz                 25.915387
# 27     dataset/1000x/A1000_2.np    Normal       rq                 14.297571
# 28     dataset/1000x/A1000_2.np    Normal       rv                 40.607115
# 29     dataset/1000x/A1000_2.np    Normal  r10_iso                 47.861445
# ...                         ...       ...      ...                       ...
# 68243   dataset/1000x/A500_2.np  Smoothed       ra                 16.348039
# 68244   dataset/1000x/A500_2.np  Smoothed       rz                 51.898691
# 68245   dataset/1000x/A500_2.np  Smoothed       rq                 20.768143
# 68246   dataset/1000x/A500_2.np  Smoothed       rv                 47.903868
# 68247   dataset/1000x/A500_2.np  Smoothed  r10_iso                 60.829687
# 68248   dataset/1000x/A500_2.np  Smoothed       ra                 16.395263
# 68249   dataset/1000x/A500_2.np  Smoothed       rz                 52.462051
# 68250   dataset/1000x/A500_2.np  Smoothed       rq                 20.819897
# 68251   dataset/1000x/A500_2.np  Smoothed       rv                 47.875458
# 68252   dataset/1000x/A500_2.np  Smoothed  r10_iso                 64.627673
# 68253   dataset/1000x/A500_2.np  Smoothed       ra                 16.427504
# 68254   dataset/1000x/A500_2.np  Smoothed       rz                 52.961070
# 68255   dataset/1000x/A500_2.np  Smoothed       rq                 20.850142
# 68256   dataset/1000x/A500_2.np  Smoothed       rv                 47.843282
# 68257   dataset/1000x/A500_2.np  Smoothed  r10_iso                 66.271619
# 68258   dataset/1000x/A500_2.np  Smoothed       ra                 16.439396
# 68259   dataset/1000x/A500_2.np  Smoothed       rz                 53.342074
# 68260   dataset/1000x/A500_2.np  Smoothed       rq                 20.844910
# 68261   dataset/1000x/A500_2.np  Smoothed       rv                 47.794866
# 68262   dataset/1000x/A500_2.np  Smoothed  r10_iso                 61.878979
# 68263   dataset/1000x/A500_2.np  Smoothed       ra                 16.463045
# 68264   dataset/1000x/A500_2.np  Smoothed       rz                 53.553437
# 68265   dataset/1000x/A500_2.np  Smoothed       rq                 20.847285
# 68266   dataset/1000x/A500_2.np  Smoothed       rv                 47.759520
# 68267   dataset/1000x/A500_2.np  Smoothed  r10_iso                 59.889001
# 68268   dataset/1000x/A500_2.np  Smoothed       ra                 16.478389
# 68269   dataset/1000x/A500_2.np  Smoothed       rz                 53.623887
# 68270   dataset/1000x/A500_2.np  Smoothed       rq                 20.855700
# 68271   dataset/1000x/A500_2.np  Smoothed       rv                 47.747749
# 68272   dataset/1000x/A500_2.np  Smoothed  r10_iso                 59.875598
#
#       Resolution
# 0          1000x
# 1          1000x
# 2          1000x
# 3          1000x
# 4          1000x
# 5          1000x
# 6          1000x
# 7          1000x
# 8          1000x
# 9          1000x
# 10         1000x
# 11         1000x
# 12         1000x
# 13         1000x
# 14         1000x
# 15         1000x
# 16         1000x
# 17         1000x
# 18         1000x
# 19         1000x
# 20         1000x
# 21         1000x
# 22         1000x
# 23         1000x
# 24         1000x
# 25         1000x
# 26         1000x
# 27         1000x
# 28         1000x
# 29         1000x
# ...          ...
# 68243       500x
# 68244       500x
# 68245       500x
# 68246       500x
# 68247       500x
# 68248       500x
# 68249       500x
# 68250       500x
# 68251       500x
# 68252       500x
# 68253       500x
# 68254       500x
# 68255       500x
# 68256       500x
# 68257       500x
# 68258       500x
# 68259       500x
# 68260       500x
# 68261       500x
# 68262       500x
# 68263       500x
# 68264       500x
# 68265       500x
# 68266       500x
# 68267       500x
# 68268       500x
# 68269       500x
# 68270       500x
# 68271       500x
# 68272       500x
#
# [68273 rows x 5 columns]

# %%
sns.set_palette("deep")
ax = sns.catplot(data=data2[data2['Variation']=='Normal'], kind='bar',  height=8.27, aspect=11.7/8.27, 
                 x='Measure', y='Statistic Value($\mu m$)', hue='Resolution')
savefig('global_measure_comparison_500x_vs_1000x.svg')

# %%
data
# Out:
#              ra         rz         rq         rv    r10_iso  \
# 0     12.319227  28.424331  14.939845  46.622550  52.688185
# 1     12.252274  27.979056  14.816711  45.489293  50.436546
# 2     12.181250  27.508076  14.691865  44.265761  50.141762
# 3     12.105322  27.010274  14.562313  43.004305  49.757928
# 4     12.028654  26.483810  14.432508  41.819984  49.638780
# 5     11.945812  25.915387  14.297571  40.607115  47.861445
# 6     11.850516  25.323390  14.156551  39.406765  47.709472
# 7     11.749963  24.878651  14.014303  38.251880  46.369810
# 8     11.650475  24.371363  13.871543  36.961795  47.231854
# 9     11.546287  23.930168  13.727030  35.628998  43.917023
# 10    11.426877  23.479252  13.572695  34.283999  44.007688
# 11    11.275113  23.269535  13.401386  33.662433  43.080786
# 12    11.126263  23.017988  13.247316  33.462121  42.315277
# 13    11.006929  22.726210  13.110162  33.254933  42.164932
# 14    10.892594  22.412707  12.984605  33.051216  41.967454
# 15    10.781189  22.111421  12.867744  32.831697  40.872782
# 16    10.670947  22.083780  12.754819  32.611708  39.625641
# 17    10.569192  22.001925  12.646789  32.370428  38.697175
# 18    10.487643  21.885159  12.547357  32.130623  38.535242
# 19    10.418808  21.737012  12.461326  31.865543  38.344523
# 20    10.357911  21.576569  12.383362  31.590949  39.831030
# 21    10.302138  21.411779  12.317046  31.285913  38.765968
# 22    10.260198  21.244305  12.260882  30.980458  38.967365
# 23    10.221037  21.080868  12.218883  30.654019  37.885629
# 24    10.171636  20.919691  12.181959  31.402144  38.172083
# 25    10.119729  20.766193  12.148490  32.218644  37.870572
# 26    10.078056  20.627912  12.123417  33.071880  35.074308
# 27    10.068762  20.525582  12.130101  33.911258  33.936639
# 28    10.076160  20.439907  12.169343  34.783612  38.244534
# 29    10.067291  20.344984  12.204623  35.728331  38.936391
# ...         ...        ...        ...        ...        ...
# 3392  14.924255  51.533114  18.245607  42.813238  46.100867
# 3393  14.901339  51.547305  18.288369  42.838773  45.866980
# 3394  14.897905  51.424593  18.362240  42.862967  47.934741
# 3395  14.893198  51.399313  18.472579  42.876749  48.047778
# 3396  14.917172  51.237022  18.595788  43.363106  48.924878
# 3397  14.950054  51.297515  18.712127  44.214311  50.971802
# 3398  15.033224  51.244587  18.835520  44.918713  51.555054
# 3399  15.177622  51.020696  18.982101  45.506686  50.692847
# 3400  15.349230  50.628098  19.160036  46.011223  53.622559
# 3401  15.512457  50.069054  19.352638  46.465080  57.385217
# 3402  15.630716  49.525333  19.546025  46.866948  58.668616
# 3403  15.690600  49.099267  19.683762  47.215827  55.915710
# 3404  15.711873  50.897676  19.791291  47.511519  56.524805
# 3405  15.721291  52.305071  19.902349  47.753843  55.564282
# 3406  15.797364  52.661726  20.031729  47.933527  58.751868
# 3407  15.906422  52.792574  20.169407  48.041357  59.163672
# 3408  16.003610  52.805417  20.304894  48.102885  59.679297
# 3409  16.083478  52.808044  20.430010  48.143944  60.023206
# 3410  16.155547  52.598742  20.529985  48.163457  57.710132
# 3411  16.188373  51.975798  20.588168  48.158525  59.117139
# 3412  16.213753  49.565827  20.620914  48.126525  58.956958
# 3413  16.240004  49.784566  20.636045  48.064807  58.408716
# 3414  16.263704  50.491658  20.665551  47.996036  59.349133
# 3415  16.302941  51.201481  20.712077  47.942806  58.497522
# 3416  16.348039  51.898691  20.768143  47.903868  60.829687
# 3417  16.395263  52.462051  20.819897  47.875458  64.627673
# 3418  16.427504  52.961070  20.850142  47.843282  66.271619
# 3419  16.439396  53.342074  20.844910  47.794866  61.878979
# 3420  16.463045  53.553437  20.847285  47.759520  59.889001
# 3421  16.478389  53.623887  20.855700  47.747749  59.875598
#
#                      File Name Variation
# 0     dataset/1000x/A1000_2.np    Normal
# 1     dataset/1000x/A1000_2.np    Normal
# 2     dataset/1000x/A1000_2.np    Normal
# 3     dataset/1000x/A1000_2.np    Normal
# 4     dataset/1000x/A1000_2.np    Normal
# 5     dataset/1000x/A1000_2.np    Normal
# 6     dataset/1000x/A1000_2.np    Normal
# 7     dataset/1000x/A1000_2.np    Normal
# 8     dataset/1000x/A1000_2.np    Normal
# 9     dataset/1000x/A1000_2.np    Normal
# 10    dataset/1000x/A1000_2.np    Normal
# 11    dataset/1000x/A1000_2.np    Normal
# 12    dataset/1000x/A1000_2.np    Normal
# 13    dataset/1000x/A1000_2.np    Normal
# 14    dataset/1000x/A1000_2.np    Normal
# 15    dataset/1000x/A1000_2.np    Normal
# 16    dataset/1000x/A1000_2.np    Normal
# 17    dataset/1000x/A1000_2.np    Normal
# 18    dataset/1000x/A1000_2.np    Normal
# 19    dataset/1000x/A1000_2.np    Normal
# 20    dataset/1000x/A1000_2.np    Normal
# 21    dataset/1000x/A1000_2.np    Normal
# 22    dataset/1000x/A1000_2.np    Normal
# 23    dataset/1000x/A1000_2.np    Normal
# 24    dataset/1000x/A1000_2.np    Normal
# 25    dataset/1000x/A1000_2.np    Normal
# 26    dataset/1000x/A1000_2.np    Normal
# 27    dataset/1000x/A1000_2.np    Normal
# 28    dataset/1000x/A1000_2.np    Normal
# 29    dataset/1000x/A1000_2.np    Normal
# ...                        ...       ...
# 3392   dataset/1000x/A500_2.np  Smoothed
# 3393   dataset/1000x/A500_2.np  Smoothed
# 3394   dataset/1000x/A500_2.np  Smoothed
# 3395   dataset/1000x/A500_2.np  Smoothed
# 3396   dataset/1000x/A500_2.np  Smoothed
# 3397   dataset/1000x/A500_2.np  Smoothed
# 3398   dataset/1000x/A500_2.np  Smoothed
# 3399   dataset/1000x/A500_2.np  Smoothed
# 3400   dataset/1000x/A500_2.np  Smoothed
# 3401   dataset/1000x/A500_2.np  Smoothed
# 3402   dataset/1000x/A500_2.np  Smoothed
# 3403   dataset/1000x/A500_2.np  Smoothed
# 3404   dataset/1000x/A500_2.np  Smoothed
# 3405   dataset/1000x/A500_2.np  Smoothed
# 3406   dataset/1000x/A500_2.np  Smoothed
# 3407   dataset/1000x/A500_2.np  Smoothed
# 3408   dataset/1000x/A500_2.np  Smoothed
# 3409   dataset/1000x/A500_2.np  Smoothed
# 3410   dataset/1000x/A500_2.np  Smoothed
# 3411   dataset/1000x/A500_2.np  Smoothed
# 3412   dataset/1000x/A500_2.np  Smoothed
# 3413   dataset/1000x/A500_2.np  Smoothed
# 3414   dataset/1000x/A500_2.np  Smoothed
# 3415   dataset/1000x/A500_2.np  Smoothed
# 3416   dataset/1000x/A500_2.np  Smoothed
# 3417   dataset/1000x/A500_2.np  Smoothed
# 3418   dataset/1000x/A500_2.np  Smoothed
# 3419   dataset/1000x/A500_2.np  Smoothed
# 3420   dataset/1000x/A500_2.np  Smoothed
# 3421   dataset/1000x/A500_2.np  Smoothed
#
# [13688 rows x 7 columns]

# %%
sns.set_palette("deep")
ax = sns.catplot(data=data2, kind='bar',  height=8.27, aspect=11.7/8.27, 
                 x='Measure', y='Statistic Value($\mu m$)', hue='Variation')
savefig('global_measure_comparison_normal_vs_smoothed.svg')

# %%
name_dict = {'ra':"$R_a$", 'rq':"$R_q$", 'rv':"$R_v$", 'rz':"$R_z$", 'r10_iso':"$R_{10(ISO)}$", 'rho':r"$\rho$", 'rho95': r"$\rho_{95}$"}
names = images_mapper.keys() - set('50% area rotate; 50% area tilt; 50% length tilt; 50% width tilt; 50% length rotate; 50% length tilt'.split('; '))
statistics = ['mean']
data = pd.DataFrame(
    [(file_name, name_dict[column], name, statistic, stat[name][column].describe()[statistic])
     for file_name, stat in circle_stats.items()
     for i,name in enumerate(names) 
     for column in stat[name].columns
     for statistic in statistics],
    columns=["File Name", 'Measure', 'Variation', 'Statistics', 'Statistic Value($\mu m$)'])

# %%
data['File Name'] = data['File Name'].apply(lambda x: x.split('/')[-1].split('_')[0][1:]+'x')

# %%
data = pd.concat([v2.assign(**{"File Name": k, "Variation": k2}) for k, v in circle_stats.items() for k2, v2 in v.items() ])
data
# Out:
#                rho      rho95                 File Name Variation
# profile
# 0        40.032757  20.834195  dataset/1000x/A1000_2.np    Normal
# 1        37.808698  15.450711  dataset/1000x/A1000_2.np    Normal
# 2        39.757906  23.416014  dataset/1000x/A1000_2.np    Normal
# 3        37.848630  21.678942  dataset/1000x/A1000_2.np    Normal
# 4        22.548314   6.960362  dataset/1000x/A1000_2.np    Normal
# 5        22.228233   6.965000  dataset/1000x/A1000_2.np    Normal
# 6        21.632911   6.975641  dataset/1000x/A1000_2.np    Normal
# 7        20.902623   7.195930  dataset/1000x/A1000_2.np    Normal
# 8        22.644623   7.206853  dataset/1000x/A1000_2.np    Normal
# 9        28.751023   7.219415  dataset/1000x/A1000_2.np    Normal
# 10       25.430346   7.234224  dataset/1000x/A1000_2.np    Normal
# 11       23.579681   7.252091  dataset/1000x/A1000_2.np    Normal
# 12       25.589925  13.136304  dataset/1000x/A1000_2.np    Normal
# 13       22.258390   7.655469  dataset/1000x/A1000_2.np    Normal
# 14       21.087848   7.930961  dataset/1000x/A1000_2.np    Normal
# 15       23.263306   7.947491  dataset/1000x/A1000_2.np    Normal
# 16       19.834295   7.859529  dataset/1000x/A1000_2.np    Normal
# 17       24.025436   7.928591  dataset/1000x/A1000_2.np    Normal
# 18       22.311539   4.352541  dataset/1000x/A1000_2.np    Normal
# 19       23.932255   6.745562  dataset/1000x/A1000_2.np    Normal
# 20       28.551990   5.211338  dataset/1000x/A1000_2.np    Normal
# 21       35.158378  12.830762  dataset/1000x/A1000_2.np    Normal
# 22       38.904999   3.166234  dataset/1000x/A1000_2.np    Normal
# 23       37.443888   3.660810  dataset/1000x/A1000_2.np    Normal
# 24       36.408590  10.819765  dataset/1000x/A1000_2.np    Normal
# 25       31.333111   5.450221  dataset/1000x/A1000_2.np    Normal
# 26       30.459863   6.814549  dataset/1000x/A1000_2.np    Normal
# 27       32.810509  11.439040  dataset/1000x/A1000_2.np    Normal
# 28       30.190874   8.175841  dataset/1000x/A1000_2.np    Normal
# 29       31.554785   5.347914  dataset/1000x/A1000_2.np    Normal
# ...            ...        ...                       ...       ...
# 3392      6.772086   2.236696   dataset/1000x/A500_2.np  Smoothed
# 3393      6.236139   3.707670   dataset/1000x/A500_2.np  Smoothed
# 3394      6.395064   2.172639   dataset/1000x/A500_2.np  Smoothed
# 3395      6.405481   2.183825   dataset/1000x/A500_2.np  Smoothed
# 3396      5.527085   2.597095   dataset/1000x/A500_2.np  Smoothed
# 3397      6.517668   2.384377   dataset/1000x/A500_2.np  Smoothed
# 3398      5.368352   2.302408   dataset/1000x/A500_2.np  Smoothed
# 3399      5.659079   2.334756   dataset/1000x/A500_2.np  Smoothed
# 3400      6.435703   1.581908   dataset/1000x/A500_2.np  Smoothed
# 3401      5.881580   2.502150   dataset/1000x/A500_2.np  Smoothed
# 3402      6.052377   2.666054   dataset/1000x/A500_2.np  Smoothed
# 3403      6.453131   2.979103   dataset/1000x/A500_2.np  Smoothed
# 3404      5.982509   2.693138   dataset/1000x/A500_2.np  Smoothed
# 3405      6.153588   2.818769   dataset/1000x/A500_2.np  Smoothed
# 3406      5.591127   2.091437   dataset/1000x/A500_2.np  Smoothed
# 3407      5.541934   2.908497   dataset/1000x/A500_2.np  Smoothed
# 3408      5.368612   2.974571   dataset/1000x/A500_2.np  Smoothed
# 3409      5.698790   2.593812   dataset/1000x/A500_2.np  Smoothed
# 3410      5.169270   2.124502   dataset/1000x/A500_2.np  Smoothed
# 3411      5.391388   2.417679   dataset/1000x/A500_2.np  Smoothed
# 3412      5.054211   1.644056   dataset/1000x/A500_2.np  Smoothed
# 3413      6.887085   2.994766   dataset/1000x/A500_2.np  Smoothed
# 3414     12.006617   3.094097   dataset/1000x/A500_2.np  Smoothed
# 3415     13.042837   3.207534   dataset/1000x/A500_2.np  Smoothed
# 3416     14.109343   3.215968   dataset/1000x/A500_2.np  Smoothed
# 3417     14.032987   2.675494   dataset/1000x/A500_2.np  Smoothed
# 3418     10.691763   2.754796   dataset/1000x/A500_2.np  Smoothed
# 3419     10.107831   2.148724   dataset/1000x/A500_2.np  Smoothed
# 3420      9.578519   2.807809   dataset/1000x/A500_2.np  Smoothed
# 3421      9.301545   2.166513   dataset/1000x/A500_2.np  Smoothed
#
# [13520 rows x 4 columns]

# %%
data2 = data.set_index(["File Name", "Variation"]).stack().reset_index()\
    .rename(columns={"level_2": "Measure", 0: "Statistic Value($\mu m$)"})
data2["Resolution"] = data2["File Name"].map(lambda x: x.split("/")[-1][1:].split("_")[0]+"x")
data2
# Out:
#                       File Name Variation Measure  Statistic Value($\mu m$)  \
# 0      dataset/1000x/A1000_2.np    Normal     rho                 40.032757
# 1      dataset/1000x/A1000_2.np    Normal   rho95                 20.834195
# 2      dataset/1000x/A1000_2.np    Normal     rho                 37.808698
# 3      dataset/1000x/A1000_2.np    Normal   rho95                 15.450711
# 4      dataset/1000x/A1000_2.np    Normal     rho                 39.757906
# 5      dataset/1000x/A1000_2.np    Normal   rho95                 23.416014
# 6      dataset/1000x/A1000_2.np    Normal     rho                 37.848630
# 7      dataset/1000x/A1000_2.np    Normal   rho95                 21.678942
# 8      dataset/1000x/A1000_2.np    Normal     rho                 22.548314
# 9      dataset/1000x/A1000_2.np    Normal   rho95                  6.960362
# 10     dataset/1000x/A1000_2.np    Normal     rho                 22.228233
# 11     dataset/1000x/A1000_2.np    Normal   rho95                  6.965000
# 12     dataset/1000x/A1000_2.np    Normal     rho                 21.632911
# 13     dataset/1000x/A1000_2.np    Normal   rho95                  6.975641
# 14     dataset/1000x/A1000_2.np    Normal     rho                 20.902623
# 15     dataset/1000x/A1000_2.np    Normal   rho95                  7.195930
# 16     dataset/1000x/A1000_2.np    Normal     rho                 22.644623
# 17     dataset/1000x/A1000_2.np    Normal   rho95                  7.206853
# 18     dataset/1000x/A1000_2.np    Normal     rho                 28.751023
# 19     dataset/1000x/A1000_2.np    Normal   rho95                  7.219415
# 20     dataset/1000x/A1000_2.np    Normal     rho                 25.430346
# 21     dataset/1000x/A1000_2.np    Normal   rho95                  7.234224
# 22     dataset/1000x/A1000_2.np    Normal     rho                 23.579681
# 23     dataset/1000x/A1000_2.np    Normal   rho95                  7.252091
# 24     dataset/1000x/A1000_2.np    Normal     rho                 25.589925
# 25     dataset/1000x/A1000_2.np    Normal   rho95                 13.136304
# 26     dataset/1000x/A1000_2.np    Normal     rho                 22.258390
# 27     dataset/1000x/A1000_2.np    Normal   rho95                  7.655469
# 28     dataset/1000x/A1000_2.np    Normal     rho                 21.087848
# 29     dataset/1000x/A1000_2.np    Normal   rho95                  7.930961
# ...                         ...       ...     ...                       ...
# 27008   dataset/1000x/A500_2.np  Smoothed     rho                  5.541934
# 27009   dataset/1000x/A500_2.np  Smoothed   rho95                  2.908497
# 27010   dataset/1000x/A500_2.np  Smoothed     rho                  5.368612
# 27011   dataset/1000x/A500_2.np  Smoothed   rho95                  2.974571
# 27012   dataset/1000x/A500_2.np  Smoothed     rho                  5.698790
# 27013   dataset/1000x/A500_2.np  Smoothed   rho95                  2.593812
# 27014   dataset/1000x/A500_2.np  Smoothed     rho                  5.169270
# 27015   dataset/1000x/A500_2.np  Smoothed   rho95                  2.124502
# 27016   dataset/1000x/A500_2.np  Smoothed     rho                  5.391388
# 27017   dataset/1000x/A500_2.np  Smoothed   rho95                  2.417679
# 27018   dataset/1000x/A500_2.np  Smoothed     rho                  5.054211
# 27019   dataset/1000x/A500_2.np  Smoothed   rho95                  1.644056
# 27020   dataset/1000x/A500_2.np  Smoothed     rho                  6.887085
# 27021   dataset/1000x/A500_2.np  Smoothed   rho95                  2.994766
# 27022   dataset/1000x/A500_2.np  Smoothed     rho                 12.006617
# 27023   dataset/1000x/A500_2.np  Smoothed   rho95                  3.094097
# 27024   dataset/1000x/A500_2.np  Smoothed     rho                 13.042837
# 27025   dataset/1000x/A500_2.np  Smoothed   rho95                  3.207534
# 27026   dataset/1000x/A500_2.np  Smoothed     rho                 14.109343
# 27027   dataset/1000x/A500_2.np  Smoothed   rho95                  3.215968
# 27028   dataset/1000x/A500_2.np  Smoothed     rho                 14.032987
# 27029   dataset/1000x/A500_2.np  Smoothed   rho95                  2.675494
# 27030   dataset/1000x/A500_2.np  Smoothed     rho                 10.691763
# 27031   dataset/1000x/A500_2.np  Smoothed   rho95                  2.754796
# 27032   dataset/1000x/A500_2.np  Smoothed     rho                 10.107831
# 27033   dataset/1000x/A500_2.np  Smoothed   rho95                  2.148724
# 27034   dataset/1000x/A500_2.np  Smoothed     rho                  9.578519
# 27035   dataset/1000x/A500_2.np  Smoothed   rho95                  2.807809
# 27036   dataset/1000x/A500_2.np  Smoothed     rho                  9.301545
# 27037   dataset/1000x/A500_2.np  Smoothed   rho95                  2.166513
#
#       Resolution
# 0          1000x
# 1          1000x
# 2          1000x
# 3          1000x
# 4          1000x
# 5          1000x
# 6          1000x
# 7          1000x
# 8          1000x
# 9          1000x
# 10         1000x
# 11         1000x
# 12         1000x
# 13         1000x
# 14         1000x
# 15         1000x
# 16         1000x
# 17         1000x
# 18         1000x
# 19         1000x
# 20         1000x
# 21         1000x
# 22         1000x
# 23         1000x
# 24         1000x
# 25         1000x
# 26         1000x
# 27         1000x
# 28         1000x
# 29         1000x
# ...          ...
# 27008       500x
# 27009       500x
# 27010       500x
# 27011       500x
# 27012       500x
# 27013       500x
# 27014       500x
# 27015       500x
# 27016       500x
# 27017       500x
# 27018       500x
# 27019       500x
# 27020       500x
# 27021       500x
# 27022       500x
# 27023       500x
# 27024       500x
# 27025       500x
# 27026       500x
# 27027       500x
# 27028       500x
# 27029       500x
# 27030       500x
# 27031       500x
# 27032       500x
# 27033       500x
# 27034       500x
# 27035       500x
# 27036       500x
# 27037       500x
#
# [27038 rows x 5 columns]

# %%
sns.set_palette("deep")
ax = sns.catplot(data=data2[data2['Variation']=='Normal'], kind='bar',  height=8.27, aspect=11.7/8.27, 
                 x='Measure', y='Statistic Value($\mu m$)', hue='File Name')
savefig('local_measure_comparison_500x_vs_1000x.svg')

# %%
sns.set_palette("deep")
ax = sns.catplot(data=data, kind='bar',  height=8.27, aspect=11.7/8.27, x='Measure', y='Statistic Value($\mu m$)', hue='Variation')
savefig('local_measure_comparison_normal_vs_smoothed.svg')

# %%
measures = circle_stats['dataset/1000x/A500_2.np']['Normal'].columns
latex_table = {'rho': r"$\rho$", 'rho95': r"$\rho_{95}$"}
data = pd.DataFrame([(file_name, latex_table[measure], value) 
                     for file_name, stat in circle_stats.items() 
                     for measure in measures
                     for value in stat['Normal'][measure]]
                   , columns = ['Resolution', 'Measure', 'Value'])

# %%
data['Resolution'] = data['Resolution'].apply(lambda x: x[-9:-5]+'x')

# %%
sns.set_palette("deep")
ax = sns.catplot(data=data, kind='bar',  height=8.27, aspect=11.7/8.27, x='Measure', y='Value', hue='Resolution')
savefig('local_measure_comparison_500x_vs_1000x.svg')
